# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\borba\Documents\GitHub\CPDC\data\202505_CPDC.csv",
    encoding='latin-1',          # ou 'iso-8859-1' ou 'cp1252' — teste um por um
    sep=';',                     # mude para ',' se for vírgula mesmo
    decimal=',',                 # importante no Brasil
    dtype=str,                   # <--- ISSO AQUI! força tudo como texto → NUNCA remove zeros
    # on_bad_lines='skip'        # opcional: pula linhas ruins
)

print(df.head(10))               # veja se os zeros estão lá
print(df.dtypes)                 # confirme que as colunas são object (string)
# Out:
#   CÓDIGO ÓRGÃO SUPERIOR                         NOME ÓRGÃO SUPERIOR  \
# 0                 53000  Ministério da Integração e do Desenvolvime
# 1                 53000  Ministério da Integração e do Desenvolvime
# 2                 53000  Ministério da Integração e do Desenvolvime
# 3                 53000  Ministério da Integração e do Desenvolvime
# 4                 53000  Ministério da Integração e do Desenvolvime
# 5                 53000  Ministério da Integração e do Desenvolvime
# 6                 53000  Ministério da Integração e do Desenvolvime
# 7                 53000  Ministério da Integração e do Desenvolvime
# 8                 53000  Ministério da Integração e do Desenvolvime
# 9                 53000  Ministério da Integração e do Desenvolvime
#
#   CÓDIGO ÓRGÃO                                         NOME ÓRGÃO  \
# 0        53000  Ministério da Integração e do Desenvolvimento ...
# 1        53000  Ministério da Integração e do Desenvolvimento ...
# 2        53000  Ministério da Integração e do Desenvolvimento ...
# 3        53000  Ministério da Integração e do Desenvolvimento ...
# 4        53000  Ministério da Integração e do Desenvolvimento ...
# 5        53000  Ministério da Integração e do Desenvolvimento ...
# 6        53000  Ministério da Integração e do Desenvolvimento ...
# 7        53000  Ministério da Integração e do Desenvolvimento ...
# 8        53000  Ministério da Integração e do Desenvolvimento ...
# 9        53000  Ministério da Integração e do Desenvolvimento ...
#
#   CÓDIGO UNIDADE GESTORA                         NOME UNIDADE GESTORA  \
# 0                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 1                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 2                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 3                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 4                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 5                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 6                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 7                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 8                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
# 9                 530012  SECRETARIA NACIONAL PROTECAO E DEFESA CIVIL
#
#   ANO EXTRATO MÊS EXTRATO    CPF PORTADOR              NOME PORTADOR  \
# 0        2025          05  ***.100.652-**    CARLOS BATISTA DA COSTA
# 1        2025          05  ***.100.652-**    CARLOS BATISTA DA COSTA
# 2        2025          05  ***.299.272-**            JOSE THOME NETO
# 3        2025          05  ***.299.272-**            JOSE THOME NETO
# 4        2025          05  ***.299.272-**            JOSE THOME NETO
# 5        2025          05  ***.795.528-**  MARIO JORGE BOUEZ ABRAHIM
# 6        2025          05  ***.795.528-**  MARIO JORGE BOUEZ ABRAHIM
# 7        2025          05  ***.795.528-**  MARIO JORGE BOUEZ ABRAHIM
# 8        2025          05  ***.731.902-**    MATEUS FERREIRA ASSAYAG
# 9        2025          05  ***.274.362-**     NAZARENO SOUZA MARTINS
#
#   CNPJ OU CPF FAVORECIDO                                    NOME FAVORECIDO  \
# 0         02367453000186                                  B. A. LUCENA LTDA
# 1         45805013000176          SM MAQUINAS, EQUIPAMENTOS E SERVICOS LTDA
# 2         07894891002160                           R J FRANCO DA SILVA LTDA
# 3         07894891002160                           R J FRANCO DA SILVA LTDA
# 4         07894891002402                           R J FRANCO DA SILVA LTDA
# 5         12440157000117  AUTO POSTO ITA COMERCIO VAREJISTA DE COMBUSTIV...
# 6         84112846000456                         DISTRIBUIDORA MENEZES LTDA
# 7         84112846000456                         DISTRIBUIDORA MENEZES LTDA
# 8         26747283000395                        L DA COSTA VASCONCELOS LTDA
# 9         42819341000133                                 A. F. BARBOSA LTDA
#
#              EXECUTOR DESPESA NÚMERO CONVÊNIO CÓDIGO CONVENENTE  \
# 0      GOVERNO DO ESTADO / AC          503350    63608947000280
# 1      GOVERNO DO ESTADO / AC          503350    63608947000280
# 2                AUTAZES / AM          503350    04477642000137
# 3                AUTAZES / AM          503350    04477642000137
# 4                AUTAZES / AM          503350    04477642000137
# 5            ITACOATIARA / AM          503350    04241980000175
# 6            ITACOATIARA / AM          503350    04241980000175
# 7            ITACOATIARA / AM          503350    04241980000175
# 8              PARINTINS / AM          503350    04329736000169
# 9  SAO PAULO DE OLIVENCA / AM          503350    05829577000124
#
#                                      NOME CONVENENTE REPASSE  \
# 0  SECRETARIA DE ESTADO DA JUSTICA E SEGURANCA PU...      Nã
# 1  SECRETARIA DE ESTADO DA JUSTICA E SEGURANCA PU...      Nã
# 2                               MUNICIPIO DE AUTAZES      Nã
# 3                               MUNICIPIO DE AUTAZES      Nã
# 4                               MUNICIPIO DE AUTAZES      Nã
# 5                           MUNICIPIO DE ITACOATIARA      Nã
# 6                           MUNICIPIO DE ITACOATIARA      Nã
# 7                           MUNICIPIO DE ITACOATIARA      Nã
# 8                             MUNICIPIO DE PARINTINS      Nã
# 9                 MUNICIPIO DE SAO PAULO DE OLIVENCA      Nã
#
#                  TRANSAÇÃO DATA TRANSAÇÃO VALOR TRANSAÇÃO
# 0  COMPRA A/V - R$ - APRES     09/04/2025         8800,00
# 1  COMPRA A/V - R$ - APRES     24/04/2025       427627,00
# 2  COMPRA A/V - R$ - APRES     14/04/2025       671625,00
# 3  COMPRA A/V - R$ - APRES     14/04/2025       220440,00
# 4  COMPRA A/V - R$ - APRES     14/04/2025        98123,40
# 5  COMPRA A/V - R$ - APRES     31/03/2025       119004,98
# 6  COMPRA A/V - R$ - APRES     31/03/2025      1295616,00
# 7  COMPRA A/V - R$ - APRES     31/03/2025       170669,40
# 8  COMPRA A/V - R$ - APRES     28/03/2025       139377,56
# 9  COMPRA A/V - R$ - APRES     17/04/2025         1296,00
# CÓDIGO ÓRGÃO SUPERIOR     object
# NOME ÓRGÃO SUPERIOR       object
# CÓDIGO ÓRGÃO              object
# NOME ÓRGÃO                object
# CÓDIGO UNIDADE GESTORA    object
# NOME UNIDADE GESTORA      object
# ANO EXTRATO               object
# MÊS EXTRATO               object
# CPF PORTADOR              object
# NOME PORTADOR             object
# CNPJ OU CPF FAVORECIDO    object
# NOME FAVORECIDO           object
# EXECUTOR DESPESA          object
# NÚMERO CONVÊNIO           object
# CÓDIGO CONVENENTE         object
# NOME CONVENENTE           object
# REPASSE                   object
# TRANSAÇÃO                 object
# DATA TRANSAÇÃO            object
# VALOR TRANSAÇÃO           object
# dtype: object

# %%
df.head()
df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   299 non-null    object
#  1   NOME ÓRGÃO SUPERIOR     299 non-null    object
#  2   CÓDIGO ÓRGÃO            299 non-null    object
#  3   NOME ÓRGÃO              266 non-null    object
#  4   CÓDIGO UNIDADE GESTORA  299 non-null    object
#  5   NOME UNIDADE GESTORA    299 non-null    object
#  6   ANO EXTRATO             299 non-null    object
#  7   MÊS EXTRATO             299 non-null    object
#  8   CPF PORTADOR            295 non-null    object
#  9   NOME PORTADOR           299 non-null    object
#  10  CNPJ OU CPF FAVORECIDO  299 non-null    object
#  11  NOME FAVORECIDO         299 non-null    object
#  12  EXECUTOR DESPESA        299 non-null    object
#  13  NÚMERO CONVÊNIO         299 non-null    object
#  14  CÓDIGO CONVENENTE       299 non-null    object
#  15  NOME CONVENENTE         299 non-null    object
#  16  REPASSE                 299 non-null    object
#  17  TRANSAÇÃO               299 non-null    object
#  18  DATA TRANSAÇÃO          299 non-null    object
#  19  VALOR TRANSAÇÃO         299 non-null    object
# dtypes: object(20)
# memory usage: 46.8+ KB
# CÓDIGO ÓRGÃO SUPERIOR      0
# NOME ÓRGÃO SUPERIOR        0
# CÓDIGO ÓRGÃO               0
# NOME ÓRGÃO                33
# CÓDIGO UNIDADE GESTORA     0
# NOME UNIDADE GESTORA       0
# ANO EXTRATO                0
# MÊS EXTRATO                0
# CPF PORTADOR               4
# NOME PORTADOR              0
# CNPJ OU CPF FAVORECIDO     0
# NOME FAVORECIDO            0
# EXECUTOR DESPESA           0
# NÚMERO CONVÊNIO            0
# CÓDIGO CONVENENTE          0
# NOME CONVENENTE            0
# REPASSE                    0
# TRANSAÇÃO                  0
# DATA TRANSAÇÃO             0
# VALOR TRANSAÇÃO            0
# dtype: int64

# %% [markdown]
# ## Análise inicial
# - 299 registros (linhas)
# - 20 variáveis (colunas)
#
# Todas as colunas estão como object, inclusive:
# - ANO EXTRATO
# - MÊS EXTRATO
# - DATA TRANSAÇÃO
# - VALOR TRANSAÇÃO
#
# Duas colunas chamam atenção:
# - NOME ORGAO: 33 nulos
# - CPF PORTADOR: 4 nulos

# %%
df_raw = df.copy()
df_clean = df.copy()

# %%
df_clean['CPF PORTADOR'] = df_clean['CPF PORTADOR'].fillna('NÃO INFORMADO')

# %%
df_clean['NOME ÓRGÃO'] = df_clean['NOME ÓRGÃO'].fillna('NÃO INFORMADO')

# %%
df_clean['VALOR TRANSAÇÃO'] = (
    df_clean['VALOR TRANSAÇÃO']
    .str.replace('.', '', regex=False)
    .str.replace(',', '.', regex=False)
    .astype(float)
)

# %%
df_clean['DATA TRANSAÇÃO'] = pd.to_datetime(
    df_clean['DATA TRANSAÇÃO'],
    format='%d/%m/%Y',
    errors='coerce'
)

# %%
df_clean['ANO EXTRATO'] = df_clean['ANO EXTRATO'].astype(int)

# %%
df_clean['MÊS EXTRATO'] = df_clean['MÊS EXTRATO'].astype(int)

# %%
df_clean.info()
df_clean.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CÓDIGO ÓRGÃO SUPERIOR   299 non-null    object
#  1   NOME ÓRGÃO SUPERIOR     299 non-null    object
#  2   CÓDIGO ÓRGÃO            299 non-null    object
#  3   NOME ÓRGÃO              299 non-null    object
#  4   CÓDIGO UNIDADE GESTORA  299 non-null    object
#  5   NOME UNIDADE GESTORA    299 non-null    object
#  6   ANO EXTRATO             299 non-null    int64
#  7   MÊS EXTRATO             299 non-null    int64
#  8   CPF PORTADOR            299 non-null    object
#  9   NOME PORTADOR           299 non-null    object
#  10  CNPJ OU CPF FAVORECIDO  299 non-null    object
#  11  NOME FAVORECIDO         299 non-null    object
#  12  EXECUTOR DESPESA        299 non-null    object
#  13  NÚMERO CONVÊNIO         299 non-null    object
#  14  CÓDIGO CONVENENTE       299 non-null    object
#  15  NOME CONVENENTE         299 non-null    object
#  16  REPASSE                 299 non-null    object
#  17  TRANSAÇÃO               299 non-null    object
#  18  DATA TRANSAÇÃO          299 non-null    datetime64[ns]
#  19  VALOR TRANSAÇÃO         299 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(16)
# memory usage: 46.8+ KB
# CÓDIGO ÓRGÃO SUPERIOR     0
# NOME ÓRGÃO SUPERIOR       0
# CÓDIGO ÓRGÃO              0
# NOME ÓRGÃO                0
# CÓDIGO UNIDADE GESTORA    0
# NOME UNIDADE GESTORA      0
# ANO EXTRATO               0
# MÊS EXTRATO               0
# CPF PORTADOR              0
# NOME PORTADOR             0
# CNPJ OU CPF FAVORECIDO    0
# NOME FAVORECIDO           0
# EXECUTOR DESPESA          0
# NÚMERO CONVÊNIO           0
# CÓDIGO CONVENENTE         0
# NOME CONVENENTE           0
# REPASSE                   0
# TRANSAÇÃO                 0
# DATA TRANSAÇÃO            0
# VALOR TRANSAÇÃO           0
# dtype: int64

# %% [markdown]
# ## Realizada Tipagem de Dados:
#
# > df_raw   → dados brutos (intocados) |
# df_clean → dados tratados (tipos, nulos, formatos)
#
# Valores nulos: CPF PORTADOR E NOME ORGAO antes **nulo** trataremos como **NÃO INFORMADO**;
# Convertemos: VALOR TRANSACAO de **object** para **float** além da virgulas e milhar; DATA TRANSACAO de **object** para **%d/%m/%Y** além de **coerce** por segurança; ANO e MES de **object** para **int**;

# %%
freq_orgao = (
    df_clean['NOME ÓRGÃO SUPERIOR']
    .value_counts()
    .head(10)
)

# %%
freq_orgao.plot(kind='barh', title='Órgãos por Número de Transações')
# Out:
# <Axes: title={'center': 'Órgãos por Número de Transações'}, ylabel='NOME ÓRGÃO SUPERIOR'>

# %% [markdown]
# Podemos ver que o **MID** concentra o maior número de transações.

# %%
freq_portador = (
    df_clean['NOME PORTADOR']
    .value_counts()
    .head(10)
)

# %%
freq_portador.plot(kind='barh', title='Top 10 Portadores por Número de Transações')
# Out:
# <Axes: title={'center': 'Top 10 Portadores por Número de Transações'}, ylabel='NOME PORTADOR'>

# %% [markdown]
# Quem mais **usou** o cartão, não necessariamente quem mais **gastou**

# %%
gasto_favorecido = (
    df_clean
    .groupby('NOME FAVORECIDO')['VALOR TRANSAÇÃO']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# %%
gasto_favorecido.plot(kind='barh', title='Top 10 Favorecidos por Valor Total Gasto')
# Out:
# <Axes: title={'center': 'Top 10 Favorecidos por Valor Total Gasto'}, ylabel='NOME FAVORECIDO'>

# %% [markdown]
# Vemos gastos com bebidas, mercados, alimentos e construtoras

# %%
gasto_portador = (
    df_clean
    .groupby('NOME PORTADOR')['VALOR TRANSAÇÃO']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# %%
gasto_portador.plot(
    kind='barh',
    title='Top 10 Portadores por Valor Total Gasto'
)
# Out:
# <Axes: title={'center': 'Top 10 Portadores por Valor Total Gasto'}, ylabel='NOME PORTADOR'>

# %% [markdown]
# Alguns portadores concentram valores elevados mesmo com menor número de transações

# %%
ticket_medio_orgao = (
    df_clean
    .groupby('NOME ÓRGÃO SUPERIOR')['VALOR TRANSAÇÃO']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

# %%
ticket_medio_orgao.plot(
    kind='barh',
    title='Top 10 Órgãos por Ticket Médio'
)
# Out:
# <Axes: title={'center': 'Top 10 Órgãos por Ticket Médio'}, ylabel='NOME ÓRGÃO SUPERIOR'>

# %% [markdown]
# Infelizmente não temos a informação do nome do orgão, e mesmo com menos transações podem apresentar ticket médio significativamente maior.

# %% [markdown]
# ## CONCLUSÃO
#
# Após a etapa de limpeza e tipagem dos dados, foi possível realizar análises univariadas e bivariadas sobre os gastos com o Cartão de Pagamento da Defesa Civil (CPDC). Observou-se que o MID concentra o maior número de transações registradas no período analisado, indicando maior frequência de uso do cartão por esse órgão.
#
# A análise dos favorecidos revelou que os gastos estão majoritariamente concentrados em estabelecimentos relacionados a bebidas, mercados, alimentos e construtoras, o que sugere despesas operacionais e logísticas típicas de ações emergenciais.
#
# Durante o processo, foi identificada a ausência de informações completas sobre o nome de alguns órgãos, o que limita análises mais detalhadas por entidade administrativa. Ainda assim, foi possível observar que órgãos ou portadores com menor número de transações podem apresentar valores médios significativamente mais altos, evidenciando diferenças relevantes no padrão de gasto.
#
# De forma geral, a análise demonstra que frequência de uso não está necessariamente associada a maior volume financeiro, reforçando a importância de avaliar simultaneamente quantidade de transações, valor total e ticket médio para uma compreensão mais precisa dos gastos públicos.
